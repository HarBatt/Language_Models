# %%
import pandas as pd

# %%
n = 60
dataframe = pd.read_csv("data.csv")
dataframe.head()
# Out:
#    Unnamed: 0                                                  0 pr-impact  \
# 0           0  On creating policy for the second time after s...       NaN
# 1           1  Attachment processing in JSS fails because the...       NaN
# 2           2  ##############################################...   Scaling
# 3           3  Description:l2circuit connections status stuck...       NaN
# 4           4  below issues are found :\n1. For Non-admin use...       NaN
#
#                                             keywords submitter-id  \
# 0                                                NaN      systest
# 1                                                NaN      systest
# 2  Services_SnP, ipsec_rli_26891_ikev1_perf_6000t...      systest
# 3  122_fortius_14650_wrk_prt_vpws_m2mdualhomed.pl...      systest
# 4                                                NaN      systest
#
#                      arrival-date problem-level  \
# 0  Sun Jan 01 11:50:46 -0800 2017         4-IL2
# 1  Sun Jan 01 22:15:56 -0800 2017         4-IL2
# 2  Mon Jan 02 01:52:00 -0800 2017         3-IL1
# 3  Mon Jan 02 02:12:14 -0800 2017         3-IL1
# 4  Mon Jan 02 02:37:30 -0800 2017         6-IL4
#
#                                             synopsis     found-during  \
# 0  Community options were not coming when we are ...  Regression test
# 1  SN:16.2R1: Attachment processing in JSS fails ...  Regression test
# 2  SERVICES_SNP_REGRESSIONS:IPSEC: Not able to es...  Regression test
# 3  RBU ACCESS REGRESSIONS:l2circuit connections s...  Regression test
# 4       Log handling on web for device is not proper  Regression test
#
#                                   platform   number              symptom  \
# 0                                 Space VA  1242610                  NaN
# 1                                      NaN  1242694                  NaN
# 2                                    MX960  1242731  unexpected-behavior
# 3  ACX1000:ACX1100:ACX2000:ACX2100:ACX2200  1242732  unexpected-behavior
# 4                                      NaN  1242736                  NaN
#
#       attributes                           category functional-area  \
# 0  regression-pr  space-asterix-l3vpn-service-order        software
# 1            NaN                    space-aim-cases        software
# 2    performance               sw-service-ipsec-mmx        software
# 3  regression-pr                         sw-acx-oam        software
# 4            NaN                        sw-embedded        software
#
#       product root-cause
# 0         csd         \n
# 1       space         \n
# 2        mx/x         \n
# 3         acx         \n
# 4  tca-series         \n

# %%
category = dataframe['category'].value_counts()[:n].index.tolist()

# %%
dataframe_new = []
for index, row in dataframe.iterrows():
    if row["category"] in category:
        dataframe_new.append(row)
        
df = pd.DataFrame(dataframe_new)

# %%
df.head()
# Out:
#     Unnamed: 0                                                  0 pr-impact  \
# 6            6  1. Create a VPLS HS service with HUB/P2P-SPOKE...       NaN
# 9            9  1. Login CSD\n2. Create VPLS order by adding E...       NaN
# 16          16  Description\n#################################...       NaN
# 21          21  \n\nLets say site setting has 25 UNIs and will...       NaN
# 22          22  Description\n\n###############################...       NaN
#
#                                              keywords submitter-id  \
# 6                                                 NaN      systest
# 9                                                 NaN      systest
# 16  RPT_RIAD 141_RLI20502_evpn_single_active_mh_FF...      systest
# 21                                                NaN      systest
# 22  REGRC, 141R4_Trinity_RLI_18922_evpn_all_active...      systest
#
#                       arrival-date problem-level  \
# 6   Mon Jan 02 04:08:49 -0800 2017         6-IL4
# 9   Mon Jan 02 08:24:36 -0800 2017         6-IL4
# 16  Tue Jan 03 01:16:45 -0800 2017         4-IL2
# 21  Tue Jan 03 05:00:10 -0800 2017         4-IL2
# 22  Tue Jan 03 05:46:22 -0800 2017         2-CL2
#
#                                              synopsis     found-during  \
# 6   CSD - VPLS - Empty Set command is adding in vi...  Regression test
# 9   CSD - VPLS - Service Order - User not able to ...  Regression test
# 16  RPT RIAD VMX Regressions :VE interfaces are no...  Regression test
# 21  CSD - VPLS - Revert in site-setting page not w...  Regression test
# 22  RPT RPD REGRESSIONS: Observed l2ald core @ pat...  Regression test
#
#    platform   number              symptom  \
# 6       NaN  1242756                  NaN
# 9       NaN  1242790                  NaN
# 16      VMX  1242921  unexpected-behavior
# 21      NaN  1242981                  NaN
# 22    MX480  1242996                 core
#
#                              attributes                          category  \
# 6                                   NaN  space-asterix-vpls-service-order
# 9                                   NaN  space-asterix-vpls-service-order
# 16      riad:reproducible:regression-pr                     sw-evpn-l2fwd
# 21                        regression-pr  space-asterix-vpls-service-order
# 22  reproducible:regression-pr:corefile                     sw-evpn-l2fwd
#
#    functional-area product root-cause
# 6         software     csd         \n
# 9         software     csd         \n
# 16        software    mx/x         \n
# 21        software     csd         \n
# 22        software    mx/x         \n

# %%
len(df['category'].value_counts())
# Out:
# 40

# %%
df
# Out:
#        Unnamed: 0                                                  0  \
# 6               6  1. Create a VPLS HS service with HUB/P2P-SPOKE...
# 9               9  1. Login CSD\n2. Create VPLS order by adding E...
# 16             16  Description\n#################################...
# 21             21  \n\nLets say site setting has 25 UNIs and will...
# 22             22  Description\n\n###############################...
# ...           ...                                                ...
# 21413       21413  {\n  "log": "/homes/vbaskara/bbe.txt",\n  "fil...
# 21429       21429  ##############################################...
# 21431       21431  {\n\nPlease move it to right category if its w...
# 21433       21433  ##############################################...
# 21449       21449  ##############################################...
#
#        pr-impact                                           keywords  \
# 6            NaN                                                NaN
# 9            NaN                                                NaN
# 16           NaN  RPT_RIAD 141_RLI20502_evpn_single_active_mh_FF...
# 21           NaN                                                NaN
# 22           NaN  REGRC, 141R4_Trinity_RLI_18922_evpn_all_active...
# ...          ...                                                ...
# 21413    Feature  Regression_reviewed,TemplatePR:LogFile:junos M...
# 21429        NaN  Regression_Scrubbed RegressionImpact: https://...
# 21431    Feature  TemplatePR,rcb_oam_mts_004_3_ex2300_sazmac, Re...
# 21433  Debugging  srx-riad, appid_mts_master_01.robot (TC4),Regr...
# 21449        NaN  Regression_Scrubbed,RegressionImpact: https://...
#
#       submitter-id                    arrival-date problem-level  \
# 6          systest  Mon Jan 02 04:08:49 -0800 2017         6-IL4
# 9          systest  Mon Jan 02 08:24:36 -0800 2017         6-IL4
# 16         systest  Tue Jan 03 01:16:45 -0800 2017         4-IL2
# 21         systest  Tue Jan 03 05:00:10 -0800 2017         4-IL2
# 22         systest  Tue Jan 03 05:46:22 -0800 2017         2-CL2
# ...            ...                             ...           ...
# 21413      systest  Thu Dec 23 23:42:38 -0800 2021         4-IL2
# 21429      systest  Mon Dec 27 21:58:05 -0800 2021         6-IL4
# 21431      systest  Mon Dec 27 23:42:32 -0800 2021         4-IL2
# 21433      systest  Tue Dec 28 03:13:02 -0800 2021         4-IL2
# 21449      systest  Wed Dec 29 10:47:04 -0800 2021         6-IL4
#
#                                                 synopsis     found-during  \
# 6      CSD - VPLS - Empty Set command is adding in vi...  Regression test
# 9      CSD - VPLS - Service Order - User not able to ...  Regression test
# 16     RPT RIAD VMX Regressions :VE interfaces are no...  Regression test
# 21     CSD - VPLS - Revert in site-setting page not w...  Regression test
# 22     RPT RPD REGRESSIONS: Observed l2ald core @ pat...  Regression test
# ...                                                  ...              ...
# 21413  JDI_REGRESSION :: SUBSCRIBER-SERVICES:: :: DHC...  Regression test
# 21429  JDI-REG: [MTS] []:Resource Unavailable :Params...  Regression test
# 21431  JDI_FT_REGRESSION:PLATFORM:SWITCHING:RCB::OAM:...  Regression test
# 21433  22.1R1:SRX-RIAD:vSRX3.0: APPID: Application Gr...  Regression test
# 21449  JDI-REG:[FIREWALL]:params file is not found in...  Regression test
#
#          platform   number              symptom  \
# 6             NaN  1242756                  NaN
# 9             NaN  1242790                  NaN
# 16            VMX  1242921  unexpected-behavior
# 21            NaN  1242981                  NaN
# 22          MX480  1242996                 core
# ...           ...      ...                  ...
# 21413       MX480  1639698  unexpected-behavior
# 21429         NaN  1639965                  NaN
# 21431  EX2300-24T  1639991  unexpected-behavior
# 21433     vSRX3.0  1640040  unexpected-behavior
# 21449         NaN  1640301                  NaN
#
#                                 attributes                          category  \
# 6                                      NaN  space-asterix-vpls-service-order
# 9                                      NaN  space-asterix-vpls-service-order
# 16         riad:reproducible:regression-pr                     sw-evpn-l2fwd
# 21                           regression-pr  space-asterix-vpls-service-order
# 22     reproducible:regression-pr:corefile                     sw-evpn-l2fwd
# ...                                    ...                               ...
# 21413           reproducible:regression-pr                         sw-jdhcpd
# 21429                                  NaN              mts-regression-infra
# 21431                                  NaN                     sw-os-freebsd
# 21433      reproducible:riad:regression-pr                    sw-dpi-ngappid
# 21449                                  NaN                      mts-firewall
#
#       functional-area                      product  \
# 6            software                          csd
# 9            software                          csd
# 16           software                         mx/x
# 21           software                          csd
# 22           software                         mx/x
# ...               ...                          ...
# 21413        software                         mx/x
# 21429      testscript                   ptx-series
# 21431        software  all-junos:ex-series:freebsd
# 21433        software                  vsrx-series
# 21449      testscript                   qfx-series
#
#                                               root-cause
# 6                                                     \n
# 9                                                     \n
# 16                                                    \n
# 21                                                    \n
# 22                                                    \n
# ...                                                  ...
# 21413                                                 \n
# 21429                                                 \n
# 21431  oam volume already mounted when snapshot attem...
# 21433  1. By the time micro app's are parsing, group ...
# 21449                                                 \n
#
# [6004 rows x 17 columns]

# %%
df.to_csv("reduced_cols.csv", encoding='utf-8')
